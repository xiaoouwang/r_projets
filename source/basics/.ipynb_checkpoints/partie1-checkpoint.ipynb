# %%
# https://www.tidytextmining.com/tfidf.html
# German
gutenberg_metadata %>%
  filter(title == "Die Leiden des jungen Werther") %>% filter(language == "de")
# English
gutenberg_metadata %>%
  filter(title == "Wuthering Heights") %>% filter(language == "en")
# French
gutenberg_metadata %>%
  filter(title == "Madame Bovary") %>% filter(language == "fr")
# Out:
#   gutenberg_id title                         author
# 1 19794        Die Leiden des jungen Werther Goethe, Johann Wolfgang von
#   gutenberg_author_id language gutenberg_bookshelf rights
# 1 586                 de       Harvard Classics    Public domain in the USA.
#   has_text
# 1 TRUE
#   gutenberg_id title             author        gutenberg_author_id language
# 1 768          Wuthering Heights Brontë, Emily 405                 en
#   gutenberg_bookshelf                                 rights
# 1 Gothic Fiction/Movie Books/Best Books Ever Listings Public domain in the USA.
#   has_text
# 1 TRUE
#   gutenberg_id title         author            gutenberg_author_id language
# 1 14155        Madame Bovary Flaubert, Gustave 574                 fr
#   gutenberg_bookshelf
# 1 Best Books Ever Listings/FR Littérature/Banned Books from Anne Haight's list
#   rights                    has_text
# 1 Public domain in the USA. TRUE

# %%
# my.name <- readline(prompt="Enter name: ")
# print(my.name)
# library(stringr)
library(tidyverse)
my.name = "3 4 5"
str_split(my.name," ")
# Out:
# [[1]]
# [1] "3" "4" "5"

# %%
install.packages("tidytext")
# Out:
# also installing the dependencies ‘SnowballC’, ‘hunspell’, ‘tokenizers’, ‘janeaustenr’
# The downloaded binary packages are in
# 	/var/folders/c7/fz0rp7d15yx8qxsngj1bspqm0000gn/T//RtmpBRZvaA/downloaded_packages

# %%
library(gutenbergr)
data(stop_words)
library(tidytext)
hgwells <- gutenberg_download(14591)
tidy_hgwells <- hgwells %>%
  unnest_tokens(word, text) %>%
  anti_join(stop_words)
hehe <- tidy_hgwells %>%
  count(word, sort = TRUE) %>%
  mutate(total = sum(n)) %>% 
  mutate(rank = row_number(), 
         `term frequency` = n/total)
# total_words
hehe %>% 
  ggplot(aes(rank, `term frequency`)) + 
  geom_line(size = 1.1, alpha = 0.8, show.legend = FALSE) + 
  scale_x_log10() +
  scale_y_log10()
# Out:
# Joining, by = "word"
# plot without title

# %%
austen <- gutenberg_download(105)
austen.persuasion <- austen$text
head(austen.persuasion)
length(austen.persuasion)
# Out:
# [1] "Persuasion"  ""            ""            "by"          ""
# [6] "Jane Austen"
# [1] 8328

# %%
austen <- gutenberg_download(25559)
austen.persuasion <- austen$text
# head(austen.persuasion)
length(austen.persuasion)
austen.persuasion
# Out:
# [1] 7163
#    [1] "題記"
#    [2] ""
#    [3] "--------------------------------------------------------------------------------"
#    [4] ""
#    [5] "　　回憶講小說史時，距今已垂十載，即印此梗概，亦已在七年之前矣。爾后研"
#    [6] "治之風，頗益盛大，顯幽燭隱，時亦有聞。如鹽谷節山〔1〕教授之發見元刊全"
#    [7] "相平話殘本及“三言”，并加考索，在小說史上，實為大事；即中國嘗有論者〔2〕，"
#    [8] "謂當有以朝代為分之小說史，亦殆非膚泛之論也。此种要略，早成陳言，惟緣別"
#    [9] "無新書，遂使尚有讀者，复將重印，義當更張，而流徙以來，斯業久廢，昔之所"
#   [10] "作，已如云煙，故僅能于第十四十五及二十一篇，稍施改訂，余則以別無新意，"
#   [11] "大率仍為舊文。大器晚成，瓦釜以久，雖延年命，亦悲荒涼，校訖黯然，誠望杰"
#   [12] "构于來哲也。"
#   [13] ""
#   [14] "　　一九三○年十一月二十五日之夜，魯迅記。"
#   [15] ""
#   [16] "　　　　　　　　　※　　　　　　　 ※　　　　　　　　 ※"
#   [17] ""
#   [18] "　　〔1〕　鹽谷節山（1878—1962）　鹽谷溫，字節山，日本漢學家。"
#   [19] "　　著有《中國文學概論講話》等。他在所著《關于明的小說“三言”》一文中，"
#   [20] "介紹了新發現的元刊全相平話五种及“三言”（載一九二四年日本漢學雜志《斯"
#   [21] "文》第八編第六號）。“平話五种”及“三言”，分別參看本書第十四篇和第二"
#   [22] "十一篇。"
#   [23] "　　〔2〕　論者　指鄭振鐸。本篇手稿原作：“鄭振鐸教授之謂當有以朝代為"
#   [24] "分之小說史，亦殆非膚泛之論也。”"
#   [25] "第一篇　史家對于小說之著錄及論述"
#   [26] ""
# ...
